# %% [markdown]
# # **Introduction To Linear Regression**
# Linear regression is method to find a __relationship__ between a
# __dependent__ variable and one or more __independent__ variables
# using a __stright line__.
#
# <img src="../images/Linear_regression.png" alt="Life Cycle of ML" width="400"  />
#
# ___
#
# # **Types of Linear Regression**
#
# ### 1. Simple Linear Regression
#
# * One independent variable X and one dependent variable Y.
#
# ### 2. Multiple Linear Regression
#
# * More than one independent variables ( predictors).
#
# ### 3. Polynomial Regression
#
# * A type of linear regression where the relationships is modeled as a polynomial (non-linear in nature).
#
# ### 4. Ridge Regression
#
# * A variant of linear regression that adds a penality (regularization) term to prevent overfitting.
#
# ### 5. Lasso Regression
#
# * Another regularization version of linear regression, using __L1 penality__ to induce sparsity.
#
# <img src="../images/linear_regression2.png" alt="linear regression" width="300" />

# %% [markdown]
# # **The Mathematics of Linear Regression**
#
#       __Least Square Method__
#
# $$
# SSE = \sum \left( Y_i - \left( \beta_0 + \beta_1 X_i \right) \right)^2
# $$
#
# ## Mathematics Behind Linear Regression
#
# __y = mx + b__
#
# y dependent variable ,x independent variable ,m slope ,b intercept.
#
#
# **Objective:** Minimize SSE to find optimal values for \( \beta_0 \) and \( \beta_1 \).
#
#
#
# ### Normal Equations:
#
# The slope coefficient:
#
# $$
# \beta_1 = \frac{\sum (X_i - \bar{X})(Y_i - \bar{Y})}{\sum (X_i - \bar{X})^2}
# $$
#
# The intercept:
#
# $$
# \beta_0 = \bar{Y} - \beta_1 \bar{X}
# $$

# %% [markdown]
# ___
#
# # **Multiple Linear Regression**
#
# __Defination__
#
# Multiple Linear Regression(MLR) is a statistical method used to predict an __Outcome(dependent variable)__ based on ___two or more input features (independent variable)__
#
# __formula__
#
# $$
# Y = b_0 + b_1X_1 + b_2X_2 + ....+ b_nX_n + \varepsilon
# $$
#
# ---

# %% [markdown]
# # **Evaluating Linear Regression Models**
#
# Common metrics to assess model performance:
#
# ### **1. Mean Absolut Error(MAE)**
#
# * Average of absolute defferences between predictions and actual values
#
#
# $$
# MAE = \frac{1}{n} \sum_{i=1}^{n} \left| y_i - \hat{y}_i \right|
# $$
#
# $$
# y_i = actual.. value
# $$
#
# $$
# hat{y}_i = predicted.. value
# $$
#
# $$
# n= number of data points
# $$
#
#
# # **2. Mean Squared Error(MSE)**
#
# * Average of squared differences between prediction and actal values.
#
# $$
# MSE = \frac{1}{n} \sum_{i=1}^{n} \left( Y_i - \hat{Y}_i \right)^2
# $$
#
# ### **3. Root Mean Squared Error(RMSE)**
#
# * Square root of MSE, provides error in original units
#
# $$
# RMSE = \sqrt{ \frac{1}{n} \sum_{i=1}^{n} \left( y_i - \hat{y}_i \right)^2 }
# $$
#
# ### **4. R-squared**
#
# * Propotion of variance explained by the model

# %% [markdown]
# ___
#
# # **Overview of Linear Regression**
#
# The linear regression workflow follow these key steps:
#
# ### **1. Define the Problem**
#
# * Identify dependent and independent variables
#
# ### **2. Collect and Prepare Data**
#
# * Clean ,Preprocess,and handle missing values.
#
# ### **3. Split Data**
#
# * Divide into training and testing
#
# ### **4. Fit the Model**
#
# * Use the liear regression equation
#
# __Y=b0+b1X+ε__
#
# ### **5. Train the Model**
#
# * Estimate coefficients using the Least Squares Method
#
# ### **6. Evaluate Performance**
#
# * Use merics like __MAE,MSE,RMSE and R2__
#
# ### **7. Make Predictions**
#
# * Apply the trained model to new data
#
# ### **8. Interpret **Results**
#
# * Analyze coefficients and impact of variables

# %% [markdown]
# ___
#
# # **Making Predictions**
#
# The linear regression prediction process follows these sequential steps:
#
# ### 1.Train the Model
#
# Fit data to learn relationships
#
# ### 2.Input New Data
#
# Provide unseen values for prediction
#
# ### 3.Apply the Equation
#
# Use
# $$
# Y=b0+b1X+...+b_nX_n
# $$
#
# ### 4.Generate Predictions
#
# Get estimated outcomes
#
# ### 5.Evaluate Accuracy
#
# Compare predictions with actual values

# %% [markdown]
# # **Common Challenges in Linear Regression**
#
# ### 1. Multicollinearity
#
# Highly correlated independent variables can distort coefficient estimates
#
# ### 2. Overfitting/Underfitting
#
# Overfitting: Model fits training data too well but fails on test data.
#
# ### 3. Outliers
#
# Extreme values can heavily influence the regression line and coefficients.
#
# ### 4.Non-Linearity
#
# Assumes a linear relationship between features and target , fails if the relationship is non-linear.
#
# ### 5. Heteroscedasticity
#
# Variance of residuals isn't constant,violating the assumption of homoscedasticity.
#
# ### 6. Autocorrelation
#
# Residuals are correlated , common in time-series data
#
# ### 7. Feature Scalling
#
# large defferences in feature scales can affect gradient descent convergence.

# %%
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Load the dataset
df = pd.read_csv("../datasets/data.csv")
# Display the first few rows of the dataset
print(df.head())
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
# Display the summary of the dataset
df.describe()
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
# Display the columns of the dataset
print("Columns in the dataset:")
print(df.columns)
print("Shape of the dataset:", df.shape)
print("Shape of the dataset:", df.shape)
print("Data types of the columns:")
print(df.dtypes)
print("check for missing values")
# Check for missing values
print(df.isnull().sum())
# Out:
# Columns in the dataset:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')
# Shape of the dataset: (528, 21)
# Shape of the dataset: (528, 21)
# Data types of the columns:
# PROVINCE                       object
# DIVISION                       object
# DISTRICT                       object
# SUB DIVISION                   object
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# ...

# %%
# select numeric columns for regression
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
print("Numeric columns for regression:", numeric_columns)
# Out:
# Numeric columns for regression: ['AREA (sq.km)', 'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)', 'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)', 'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)', 'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)', 'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)', 'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)', 'ANNUAL GROWTH RATE (URBAN)']

# %%
# remove numeric columns that are not suitable for regression
# For example, if 'id' is a column that should not be used in regression    
numeric_columns = numeric_columns.drop(['id', 'date', 'time'], errors='ignore')
print("Filtered numeric columns for regression:", numeric_columns)
# Out:
# Filtered numeric columns for regression: Index(['AREA (sq.km)', 'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
# Define feature X and target Y
X =df[['MALE (URBAN)']]
Y = df['FEMALE (URBAN)']  # Assuming '
# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# Create a Linear Regression model
model = LinearRegression()  
# Fit the model to the training data
model.fit(X_train, Y_train)

# Make predictions on the test set
Y_pred = model.predict(X_test)

# %%
# plot regression line
plt.scatter(X_test, Y_test, color='blue', label='Actual Data')
plt.plot(X_test, Y_pred, color='red', linewidth=2, label='regression line')
plt.xlabel('Male (Urban)')
plt.ylabel('Female (Urban)')
plt.title('Linear Regression: Male (Urban) vs Female (Urban )')
plt.legend()
plt.show()

# %%
# Display model coefficients
print("Model Coefficients:")
print(f'Intercept: {model.intercept_}')   
print(f'model.coef_: {model.coef_[0]}')  # Coefficients for the features
# Out:
# Model Coefficients:
# Intercept: 474.9245947855743
# model.coef_: 0.9269396251607169
